# %% [markdown]
# # QSIprep's connectivity matrices
#
#
#
# ## MRTrix

# %%
# %pylab inline
from scipy.io.matlab import loadmat
from nilearn.plotting import plot_matrix

mrtrix_count_matrix = loadmat(
    "/Users/mcieslak/projects/qsiprep/scratch/crash/recon_output/qsirecon/"
    "sub-1808u/ses-1/dwi/sub-1808u_ses-1_space-T1w_desc-preproc_space-T1w_msmtconnectome.mat")
print(mrtrix_count_matrix.keys())
# Out:
# Populating the interactive namespace from numpy and matplotlib
# dict_keys(['__header__', '__version__', '__globals__', 'schaefer100_region_ids', 'schaefer100_region_labels', 'schaefer100_sum_invroiscale_connectivity', 'schaefer100_sum_invroiscale_tck', 'schaefer100_sum_invroiscale_image', 'schaefer200_region_ids', 'schaefer200_region_labels', 'schaefer200_sum_invroiscale_connectivity', 'schaefer200_sum_invroiscale_tck', 'schaefer200_sum_invroiscale_image'])

# %%
plot_matrix(mrtrix_count_matrix['schaefer100_sum_invroiscale_connectivity'],
            title="Schaefer100 InvROI Scale SIFT2 Count")

# %%
plot_matrix(mrtrix_count_matrix['schaefer200_sum_invroiscale_connectivity'],
            title="Schaefer200 InvROI Scale SIFT2 Count")

# %% [markdown]
# ## DSI Studio

# %%
dsi_studio_count = loadmat(
    "/Users/mcieslak/projects/qsiprep/scratch/crash/recon_output/qsirecon/sub-1808u/"
    "ses-1/dwi/sub-1808u_ses-1_space-T1w_desc-preproc_space-T1w_rec-3dshore_control.mat")
print(dsi_studio_count.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'schaefer100_region_ids', 'schaefer100_region_labels', 'schaefer100_count_end_connectivity', 'schaefer100_count_pass_connectivity', 'schaefer100_mean_length_end_connectivity', 'schaefer100_ncount_pass_connectivity', 'schaefer100_ncount_end_connectivity', 'schaefer100_mean_length_pass_connectivity', 'schaefer200_region_ids', 'schaefer200_region_labels', 'schaefer200_count_pass_connectivity', 'schaefer200_ncount_pass_connectivity', 'schaefer200_mean_length_pass_connectivity', 'schaefer200_mean_length_end_connectivity', 'schaefer200_ncount_end_connectivity', 'schaefer200_count_end_connectivity', 'schaefer100_count_end_connectivity_modal_ctl', 'schaefer100_count_end_connectivity_ave_ctl', 'schaefer100_count_pass_connectivity_modal_ctl', 'schaefer100_count_pass_connectivity_ave_ctl', 'schaefer100_mean_length_end_connectivity_modal_ctl', 'schaefer100_mean_length_end_connectivity_ave_ctl', 'schaefer100_ncount_pass_connectivity_modal_ctl
# ...

# %%
plot_matrix(dsi_studio_count['schaefer100_count_pass_connectivity'],
            title="Schaefer100 Pass Count")

# %%
plot_matrix(dsi_studio_count['schaefer200_count_pass_connectivity'],
            title="Schaefer200 Pass Count")
